# %% [markdown]
# This is a markdown cell.

# %%
# This is a code cell

for i in range(5,17):
    print('This line is going to print an integer ' + str(i))
# Out:
# This line is going to print an integer 5
# This line is going to print an integer 6
# This line is going to print an integer 7
# This line is going to print an integer 8
# This line is going to print an integer 9
# This line is going to print an integer 10
# This line is going to print an integer 11
# This line is going to print an integer 12
# This line is going to print an integer 13
# This line is going to print an integer 14
# This line is going to print an integer 15
# This line is going to print an integer 16
